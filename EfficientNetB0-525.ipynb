# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import pandas as pd

model_path = './archive/EfficientNetB0-525.h5'
# Define the custom metric function
model= tf.keras.models.load_model(model_path, custom_objects={'F1_score':'F1_score'})

# Now you should be able to load the model without the Unknown metric function error

# %%
img_path = 'ZEBRA DOVE 1.jpg'
img = image.load_img(img_path, target_size=(224, 224), color_mode="rgb") 
#img.show()# Adjust the target size based on EfficientNetB0 requirements
img_array = image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
predictions = model.predict(img_array)
predictions
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[2.78627823e-07, 1.47106732e-07, 6.21390051e-09, 2.59211830e-09,
#         3.40710176e-06, 9.22477525e-08, 5.77579272e-07, 2.26528440e-09,
#         8.64952625e-08, 1.24391661e-08, 2.94349274e-08, 1.09112692e-08,
#         3.16490159e-08, 7.78893718e-06, 3.17868110e-09, 8.28356939e-09,
#         1.22260872e-07, 1.21807844e-08, 8.13561982e-08, 1.60585927e-08,
#         8.18146262e-08, 8.77486741e-08, 5.70192981e-07, 1.06531090e-07,
#         2.04769531e-05, 1.31538238e-08, 1.43098930e-07, 7.64747554e-08,
#         1.21983220e-07, 2.75038701e-07, 6.97250584e-07, 7.32712868e-09,
#         2.69916342e-07, 9.28330408e-08, 5.35016165e-09, 1.51075582e-07,
#         2.66328737e-10, 9.88956344e-07, 1.68069676e-06, 7.04847380e-09,
#         4.21663430e-07, 3.86509003e-09, 7.04006666e-08, 2.56600799e-07,
#         4.86042850e-08, 8.94344453e-07, 2.42268321e-08, 1.84158424e-07,
# ...

# %%
top_k_values, top_k_indices = tf.math.top_k(predictions[0], k=3)

# %%
# Adjust top parameter based on your requirements
csv_file_path = './archive/birds.csv'  # Replace with the actual path
class_mapping_df = pd.read_csv(csv_file_path)

unique_labels = class_mapping_df["labels"].unique()
top_k_class_names = [unique_labels[idx] for idx in top_k_indices]
top_k_probabilities = predictions[0][top_k_indices]
top_k_class_names
# Out:
# ['BLACK BREASTED PUFFBIRD', 'WILD TURKEY', 'OVENBIRD']
