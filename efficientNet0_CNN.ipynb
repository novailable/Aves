# %%
# Import Data Science Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Tensorflow Libraries
from tensorflow import keras

from tensorflow.keras import layers,models
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.applications import MobileNetV2, EfficientNetB0
from tensorflow.keras.models import load_model
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing
import cv2
# System libraries
from pathlib import Path
import os.path
import random
from PIL import Image, ImageChops, ImageEnhance

# Visualization Libraries
import matplotlib.cm as cm
#!pip install cv2
#import cv2
import seaborn as sns

sns.set_style('darkgrid')

# Metrics
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
### We create a bunch of helpful functions throughout the course.
### Storing them here so they're easily accessible.

# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224, scale=True):
  """
  Reads in an image from filename, turns it into a tensor and reshapes into
  (224, 224, 3).

  Parameters
  ----------
  filename (str): string filename of target image
  img_shape (int): size to resize target image to, default 224
  scale (bool): whether to scale pixel values to range(0, 1), default True
  """
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode it into a tensor
  img = tf.image.decode_jpeg(img)
  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/255.
  else:
    return img

# Note: The following confusion matrix code is a remix of Scikit-Learn's 
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")
  
# Make a function to predict on images and plot them (works with multi-class)
def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  if len(pred[0]) > 1: # check for multi-class
    pred_class = class_names[pred.argmax()] # if more than one output, take the max
  else:
    pred_class = class_names[int(tf.round(pred)[0][0])] # if only one output, round

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);
  
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
  """
  Creates a TensorBoard callback instand to store log files.

  Stores log files with the filepath:
    "dir_name/experiment_name/current_datetime/"

  Args:
    dir_name: target directory to store TensorBoard log files
    experiment_name: name of experiment directory (e.g. efficientnet_model_1)
  """
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# Plot the validation and training data separately
import matplotlib.pyplot as plt

def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.

  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

def compare_historys(original_history, new_history, initial_epochs=5):
    """
    Compares two TensorFlow model History objects.
    
    Args:
      original_history: History object from original model (before new_history)
      new_history: History object from continued model training (after original_history)
      initial_epochs: Number of epochs in original_history (new_history plot starts from here) 
    """
    
    # Get original history measurements
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]

    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    # Combine original history with new history
    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]

    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    # Make plots
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
  
# Create function to unzip a zipfile into current working directory 
# (since we're going to be downloading and unzipping a few files)
import zipfile

def unzip_data(filename):
  """
  Unzips filename into the current working directory.

  Args:
    filename (str): a filepath to a target zip folder to be unzipped.
  """
  zip_ref = zipfile.ZipFile(filename, "r")
  zip_ref.extractall()
  zip_ref.close()

# Walk through an image classification directory and find out how many files (images)
# are in each subdirectory.
import os

def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.

  Args:
    dir_path (str): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
    
# Function to evaluate: accuracy, precision, recall, f1-score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def calculate_results(y_true, y_pred):
  """
  Calculates model accuracy, precision, recall and f1 score of a binary classification model.

  Args:
      y_true: true labels in the form of a 1D array
      y_pred: predicted labels in the form of a 1D array

  Returns a dictionary of accuracy, precision, recall, f1-score.
  """
  # Calculate model accuracy
  model_accuracy = accuracy_score(y_true, y_pred) * 100
  # Calculate model precision, recall and f1 score using "weighted average
  model_precision, model_recall, model_f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
  model_results = {"accuracy": model_accuracy,
                  "precision": model_precision,
                  "recall": model_recall,
                  "f1": model_f1}
  return model_results

# %%
BATCH_SIZE = 32
TARGET_SIZE = (224, 224)

# %%
dataset = "./archive/train"
walk_through_dir(dataset);
# Out:
# There are 525 directories and 0 images in './archive/train'.
# There are 0 directories and 139 images in './archive/train/CREAM COLORED WOODPECKER'.
# There are 0 directories and 197 images in './archive/train/CAMPO FLICKER'.
# There are 0 directories and 189 images in './archive/train/RUFUOS MOTMOT'.
# There are 0 directories and 175 images in './archive/train/WHITE TAILED TROPIC'.
# There are 0 directories and 143 images in './archive/train/KOOKABURRA'.
# There are 0 directories and 181 images in './archive/train/TREE SWALLOW'.
# There are 0 directories and 208 images in './archive/train/ORNATE HAWK EAGLE'.
# There are 0 directories and 139 images in './archive/train/AMERICAN REDSTART'.
# There are 0 directories and 157 images in './archive/train/EASTERN TOWEE'.
# There are 0 directories and 159 images in './archive/train/IBERIAN MAGPIE'.
# There are 0 directories and 155 images in './archive/train/HOOPOES'.
# There are 0 directories and 188 images in './archive/train/PHAINOPEPLA'.
# There are 0 directories and 154 images in './archive/train/BELTED KINGFISHER'.
# There are 0 directories and 155 images in './archive/train/CRESTED CARACARA'.
# There are 0 directories and 144 images in './archive/train/IMPERIAL SHAQ'.
# There are 0 directories and 201 images in './archive/train/VIOLET GREEN SWALLOW'.
# There are 0 directories and 149 images in './archive/train/CAPE MAY WARBLER'.
# There are 0 directories and 190 images in './archive/train/EASTERN MEADOWLARK'.
# There are 0 directories and 135 images in './archive/train/EUROPEAN GOLDFINCH'.
# There are 0 directories and 155 images in './archive/train/HOATZIN'.
# There are 0 directories and 136 images in './archive/train/TAIWAN MAGPIE'.
# There are 0 directories and 146 images in './archive/train/RED BELLIED PITTA'.
# There are 0 directories and 136 images in './archive/train/BARRED PUFFBIRD'.
# There are 0 directories and 161 images in './archive/train/SNOWY OWL'.
# There are 0 directories and 160 images in './archive/train/NORTHERN GOSHAWK'.
# There are 0 directories and 188 images in './archive/train/BLACK VENTED SHEARWATER'.
# There are 0 directories and 154 images in './archive/train/AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 164 images in './archive/train/ASHY THRUSHBIRD'.
# There are 0 directories and 153 images in './archive/train/BANDED STILT'.
# There are 0 directories and 144 images in './archive/train/COPPERY TAILED COUCAL'.
# There are 0 directories and 130 images in './archive/train/NORTHERN RED BISHOP'.
# There are 0 directories and 153 images in './archive/train/PURPLE FINCH'.
# There are 0 directories and 177 images in './archive/train/CABOTS TRAGOPAN'.
# There are 0 directories and 161 images in './archive/train/TAKAHE'.
# There are 0 directories and 156 images in './archive/train/SANDHILL CRANE'.
# There are 0 directories and 136 images in './archive/train/KING VULTURE'.
# There are 0 directories and 175 images in './archive/train/SHOEBILL'.
# There are 0 directories and 199 images in './archive/train/GREY HEADED CHACHALACA'.
# There are 0 directories and 193 images in './archive/train/ROSEATE SPOONBILL'.
# There are 0 directories and 137 images in './archive/train/TRUMPTER SWAN'.
# There are 0 directories and 193 images in './archive/train/AMERICAN DIPPER'.
# There are 0 directories and 137 images in './archive/train/BLACK-NECKED GREBE'.
# There are 0 directories and 152 images in './archive/train/FIORDLAND PENGUIN'.
# There are 0 directories and 158 images in './archive/train/AMERICAN COOT'.
# There are 0 directories and 160 images in './archive/train/HEPATIC TANAGER'.
# There are 0 directories and 166 images in './archive/train/PUFFIN'.
# There are 0 directories and 134 images in './archive/train/BLACKBURNIAM WARBLER'.
# There are 0 directories and 137 images in './archive/train/NORTHERN FULMAR'.
# There are 0 directories and 163 images in './archive/train/BROWN THRASHER'.
# There are 0 directories and 179 images in './archive/train/AFRICAN PYGMY GOOSE'.
# There are 0 directories and 160 images in './archive/train/PALILA'.
# There are 0 directories and 143 images in './archive/train/JABIRU'.
# There are 0 directories and 139 images in './archive/train/ANNAS HUMMINGBIRD'.
# There are 0 directories and 151 images in './archive/train/HIMALAYAN MONAL'.
# There are 0 directories and 152 images in './archive/train/CRESTED COUA'.
# There are 0 directories and 155 images in './archive/train/PARAKETT  AUKLET'.
# There are 0 directories and 157 images in './archive/train/NOISY FRIARBIRD'.
# There are 0 directories and 160 images in './archive/train/CALIFORNIA GULL'.
# There are 0 directories and 161 images in './archive/train/PARUS MAJOR'.
# There are 0 directories and 152 images in './archive/train/VENEZUELIAN TROUPIAL'.
# There are 0 directories and 211 images in './archive/train/WOOD THRUSH'.
# There are 0 directories and 151 images in './archive/train/BIRD OF PARADISE'.
# There are 0 directories and 167 images in './archive/train/RED FACED WARBLER'.
# There are 0 directories and 152 images in './archive/train/EMPEROR PENGUIN'.
# There are 0 directories and 165 images in './archive/train/CHINESE BAMBOO PARTRIDGE'.
# There are 0 directories and 200 images in './archive/train/RED KNOT'.
# There are 0 directories and 185 images in './archive/train/PUNA TEAL'.
# There are 0 directories and 162 images in './archive/train/GYRFALCON'.
# There are 0 directories and 167 images in './archive/train/RED FODY'.
# There are 0 directories and 163 images in './archive/train/EMU'.
# There are 0 directories and 163 images in './archive/train/JOCOTOCO ANTPITTA'.
# There are 0 directories and 133 images in './archive/train/BLACK-CAPPED CHICKADEE'.
# There are 0 directories and 197 images in './archive/train/KNOB BILLED DUCK'.
# There are 0 directories and 132 images in './archive/train/BARROWS GOLDENEYE'.
# There are 0 directories and 142 images in './archive/train/MAGPIE GOOSE'.
# There are 0 directories and 162 images in './archive/train/GUINEA TURACO'.
# There are 0 directories and 152 images in './archive/train/BALD IBIS'.
# There are 0 directories and 135 images in './archive/train/RUBY THROATED HUMMINGBIRD'.
# There are 0 directories and 154 images in './archive/train/PURPLE SWAMPHEN'.
# There are 0 directories and 136 images in './archive/train/AZURE JAY'.
# There are 0 directories and 156 images in './archive/train/BLACK VULTURE'.
# There are 0 directories and 138 images in './archive/train/EUROPEAN TURTLE DOVE'.
# There are 0 directories and 135 images in './archive/train/STORK BILLED KINGFISHER'.
# There are 0 directories and 163 images in './archive/train/GREAT JACAMAR'.
# There are 0 directories and 163 images in './archive/train/ABBOTTS BABBLER'.
# There are 0 directories and 142 images in './archive/train/WATTLED LAPWING'.
# There are 0 directories and 137 images in './archive/train/BALTIMORE ORIOLE'.
# There are 0 directories and 155 images in './archive/train/GROVED BILLED ANI'.
# There are 0 directories and 160 images in './archive/train/CASSOWARY'.
# There are 0 directories and 167 images in './archive/train/HAWFINCH'.
# There are 0 directories and 160 images in './archive/train/BALD EAGLE'.
# There are 0 directories and 133 images in './archive/train/CAPUCHINBIRD'.
# There are 0 directories and 176 images in './archive/train/GOLDEN CHEEKED WARBLER'.
# There are 0 directories and 173 images in './archive/train/BLACK NECKED STILT'.
# There are 0 directories and 233 images in './archive/train/OVENBIRD'.
# There are 0 directories and 156 images in './archive/train/RUFOUS KINGFISHER'.
# There are 0 directories and 170 images in './archive/train/BLUE GROSBEAK'.
# There are 0 directories and 131 images in './archive/train/INDIAN BUSTARD'.
# There are 0 directories and 173 images in './archive/train/HORNED LARK'.
# There are 0 directories and 209 images in './archive/train/MERLIN'.
# There are 0 directories and 144 images in './archive/train/STRIPPED MANAKIN'.
# There are 0 directories and 152 images in './archive/train/ARARIPE MANAKIN'.
# There are 0 directories and 172 images in './archive/train/COLLARED CRESCENTCHEST'.
# There are 0 directories and 149 images in './archive/train/HORNED SUNGEM'.
# There are 0 directories and 162 images in './archive/train/CARMINE BEE-EATER'.
# There are 0 directories and 167 images in './archive/train/BLUE HERON'.
# There are 0 directories and 197 images in './archive/train/ROSE BREASTED COCKATOO'.
# There are 0 directories and 165 images in './archive/train/HYACINTH MACAW'.
# There are 0 directories and 183 images in './archive/train/MASKED BOBWHITE'.
# There are 0 directories and 155 images in './archive/train/YELLOW CACIQUE'.
# There are 0 directories and 130 images in './archive/train/SNOWY PLOVER'.
# There are 0 directories and 138 images in './archive/train/KIWI'.
# There are 0 directories and 155 images in './archive/train/UMBRELLA BIRD'.
# There are 0 directories and 154 images in './archive/train/EASTERN BLUEBIRD'.
# There are 0 directories and 154 images in './archive/train/EURASIAN MAGPIE'.
# There are 0 directories and 154 images in './archive/train/LESSER ADJUTANT'.
# There are 0 directories and 147 images in './archive/train/AMERICAN ROBIN'.
# There are 0 directories and 170 images in './archive/train/CHESTNUT WINGED CUCKOO'.
# There are 0 directories and 139 images in './archive/train/COMMON FIRECREST'.
# There are 0 directories and 132 images in './archive/train/CHESTNET BELLIED EUPHONIA'.
# There are 0 directories and 137 images in './archive/train/CURL CRESTED ARACURI'.
# There are 0 directories and 160 images in './archive/train/CANARY'.
# There are 0 directories and 154 images in './archive/train/EARED PITA'.
# There are 0 directories and 197 images in './archive/train/SAYS PHOEBE'.
# There are 0 directories and 165 images in './archive/train/TOWNSENDS WARBLER'.
# There are 0 directories and 137 images in './archive/train/CHATTERING LORY'.
# There are 0 directories and 200 images in './archive/train/PLUSH CRESTED JAY'.
# There are 0 directories and 153 images in './archive/train/SAMATRAN THRUSH'.
# There are 0 directories and 155 images in './archive/train/BLACK SKIMMER'.
# There are 0 directories and 175 images in './archive/train/GLOSSY IBIS'.
# There are 0 directories and 154 images in './archive/train/YELLOW BELLIED FLOWERPECKER'.
# There are 0 directories and 200 images in './archive/train/SORA'.
# There are 0 directories and 187 images in './archive/train/MCKAYS BUNTING'.
# There are 0 directories and 152 images in './archive/train/RED WINGED BLACKBIRD'.
# There are 0 directories and 141 images in './archive/train/AZURE BREASTED PITTA'.
# There are 0 directories and 132 images in './archive/train/BALI STARLING'.
# There are 0 directories and 152 images in './archive/train/SQUACCO HERON'.
# There are 0 directories and 184 images in './archive/train/SPOTTED WHISTLING DUCK'.
# There are 0 directories and 154 images in './archive/train/BORNEAN BRISTLEHEAD'.
# There are 0 directories and 144 images in './archive/train/CHINESE POND HERON'.
# There are 0 directories and 155 images in './archive/train/BULWERS PHEASANT'.
# There are 0 directories and 158 images in './archive/train/BARN OWL'.
# There are 0 directories and 164 images in './archive/train/SHORT BILLED DOWITCHER'.
# There are 0 directories and 175 images in './archive/train/HARPY EAGLE'.
# There are 0 directories and 183 images in './archive/train/BREWERS BLACKBIRD'.
# There are 0 directories and 152 images in './archive/train/CRESTED NUTHATCH'.
# There are 0 directories and 156 images in './archive/train/BLACK BAZA'.
# There are 0 directories and 138 images in './archive/train/GILDED FLICKER'.
# There are 0 directories and 161 images in './archive/train/SRI LANKA BLUE MAGPIE'.
# There are 0 directories and 185 images in './archive/train/SURF SCOTER'.
# There are 0 directories and 207 images in './archive/train/OYSTER CATCHER'.
# There are 0 directories and 208 images in './archive/train/MILITARY MACAW'.
# There are 0 directories and 160 images in './archive/train/WHITE NECKED RAVEN'.
# There are 0 directories and 187 images in './archive/train/AMERICAN WIGEON'.
# There are 0 directories and 165 images in './archive/train/GREAT TINAMOU'.
# There are 0 directories and 155 images in './archive/train/NORTHERN CARDINAL'.
# There are 0 directories and 169 images in './archive/train/VULTURINE GUINEAFOWL'.
# There are 0 directories and 140 images in './archive/train/GOLDEN BOWER BIRD'.
# There are 0 directories and 155 images in './archive/train/VERMILION FLYCATHER'.
# There are 0 directories and 160 images in './archive/train/SPANGLED COTINGA'.
# There are 0 directories and 143 images in './archive/train/STRIPED OWL'.
# There are 0 directories and 135 images in './archive/train/HOODED MERGANSER'.
# There are 0 directories and 168 images in './archive/train/AZARAS SPINETAIL'.
# There are 0 directories and 144 images in './archive/train/BLONDE CRESTED WOODPECKER'.
# There are 0 directories and 187 images in './archive/train/TAWNY FROGMOUTH'.
# There are 0 directories and 140 images in './archive/train/DUSKY ROBIN'.
# There are 0 directories and 160 images in './archive/train/BUSH TURKEY'.
# There are 0 directories and 156 images in './archive/train/IVORY GULL'.
# There are 0 directories and 233 images in './archive/train/D-ARNAUDS BARBET'.
# There are 0 directories and 161 images in './archive/train/ALBERTS TOWHEE'.
# There are 0 directories and 162 images in './archive/train/CACTUS WREN'.
# There are 0 directories and 140 images in './archive/train/NORTHERN MOCKINGBIRD'.
# There are 0 directories and 263 images in './archive/train/RUFOUS TREPE'.
# There are 0 directories and 150 images in './archive/train/EASTERN WIP POOR WILL'.
# There are 0 directories and 160 images in './archive/train/FAIRY BLUEBIRD'.
# There are 0 directories and 131 images in './archive/train/MASKED LAPWING'.
# There are 0 directories and 142 images in './archive/train/GANG GANG COCKATOO'.
# There are 0 directories and 163 images in './archive/train/MALACHITE KINGFISHER'.
# There are 0 directories and 196 images in './archive/train/STRIATED CARACARA'.
# There are 0 directories and 190 images in './archive/train/LOGGERHEAD SHRIKE'.
# There are 0 directories and 130 images in './archive/train/RED TAILED THRUSH'.
# There are 0 directories and 164 images in './archive/train/WHITE THROATED BEE EATER'.
# There are 0 directories and 202 images in './archive/train/YELLOW BREASTED CHAT'.
# There are 0 directories and 154 images in './archive/train/APAPANE'.
# There are 0 directories and 162 images in './archive/train/RED WISKERED BULBUL'.
# There are 0 directories and 202 images in './archive/train/RED TAILED HAWK'.
# There are 0 directories and 161 images in './archive/train/COMMON LOON'.
# There are 0 directories and 132 images in './archive/train/ORANGE BRESTED BUNTING'.
# There are 0 directories and 154 images in './archive/train/PINK ROBIN'.
# There are 0 directories and 161 images in './archive/train/WHITE BREASTED WATERHEN'.
# There are 0 directories and 183 images in './archive/train/INDIAN ROLLER'.
# There are 0 directories and 182 images in './archive/train/CLARKS GREBE'.
# There are 0 directories and 162 images in './archive/train/JANDAYA PARAKEET'.
# There are 0 directories and 138 images in './archive/train/SCARLET IBIS'.
# There are 0 directories and 165 images in './archive/train/BLACK TAIL CRAKE'.
# There are 0 directories and 157 images in './archive/train/GREATER PEWEE'.
# There are 0 directories and 166 images in './archive/train/BANDED PITA'.
# There are 0 directories and 135 images in './archive/train/BLACK THROATED WARBLER'.
# There are 0 directories and 155 images in './archive/train/IWI'.
# There are 0 directories and 161 images in './archive/train/CALIFORNIA QUAIL'.
# There are 0 directories and 150 images in './archive/train/ALTAMIRA YELLOWTHROAT'.
# There are 0 directories and 154 images in './archive/train/BRANDT CORMARANT'.
# There are 0 directories and 157 images in './archive/train/LAZULI BUNTING'.
# There are 0 directories and 154 images in './archive/train/PHILIPPINE EAGLE'.
# There are 0 directories and 154 images in './archive/train/MIKADO  PHEASANT'.
# There are 0 directories and 193 images in './archive/train/WRENTIT'.
# There are 0 directories and 136 images in './archive/train/FAIRY TERN'.
# There are 0 directories and 134 images in './archive/train/ANDEAN GOOSE'.
# There are 0 directories and 176 images in './archive/train/PARADISE TANAGER'.
# There are 0 directories and 212 images in './archive/train/RED BILLED TROPICBIRD'.
# There are 0 directories and 193 images in './archive/train/VARIED THRUSH'.
# There are 0 directories and 203 images in './archive/train/DARK EYED JUNCO'.
# There are 0 directories and 148 images in './archive/train/DOUBLE BARRED FINCH'.
# There are 0 directories and 160 images in './archive/train/EASTERN ROSELLA'.
# There are 0 directories and 153 images in './archive/train/GAMBELS QUAIL'.
# There are 0 directories and 197 images in './archive/train/RED BEARDED BEE EATER'.
# There are 0 directories and 158 images in './archive/train/GREY PLOVER'.
# There are 0 directories and 139 images in './archive/train/DEMOISELLE CRANE'.
# There are 0 directories and 131 images in './archive/train/GO AWAY BIRD'.
# There are 0 directories and 137 images in './archive/train/MANGROVE CUCKOO'.
# There are 0 directories and 162 images in './archive/train/ELLIOTS  PHEASANT'.
# There are 0 directories and 164 images in './archive/train/AMERICAN FLAMINGO'.
# There are 0 directories and 187 images in './archive/train/SNOWY SHEATHBILL'.
# There are 0 directories and 154 images in './archive/train/WHITE BROWED CRAKE'.
# There are 0 directories and 159 images in './archive/train/GOLD WING WARBLER'.
# There are 0 directories and 169 images in './archive/train/RED LEGGED HONEYCREEPER'.
# There are 0 directories and 163 images in './archive/train/VISAYAN HORNBILL'.
# There are 0 directories and 139 images in './archive/train/DUSKY LORY'.
# There are 0 directories and 213 images in './archive/train/CASPIAN TERN'.
# There are 0 directories and 163 images in './archive/train/CROW'.
# There are 0 directories and 140 images in './archive/train/RAINBOW LORIKEET'.
# There are 0 directories and 153 images in './archive/train/PURPLE GALLINULE'.
# There are 0 directories and 179 images in './archive/train/AMERICAN AVOCET'.
# There are 0 directories and 157 images in './archive/train/ORIENTAL BAY OWL'.
# There are 0 directories and 163 images in './archive/train/RUDDY SHELDUCK'.
# There are 0 directories and 144 images in './archive/train/KAGU'.
# There are 0 directories and 142 images in './archive/train/BLACK AND YELLOW BROADBILL'.
# There are 0 directories and 150 images in './archive/train/GOLDEN PARAKEET'.
# There are 0 directories and 134 images in './archive/train/HARLEQUIN QUAIL'.
# There are 0 directories and 161 images in './archive/train/COMMON POORWILL'.
# There are 0 directories and 160 images in './archive/train/RUDY KINGFISHER'.
# There are 0 directories and 150 images in './archive/train/ANIANIAU'.
# There are 0 directories and 177 images in './archive/train/FLAME TANAGER'.
# There are 0 directories and 152 images in './archive/train/BORNEAN PHEASANT'.
# There are 0 directories and 190 images in './archive/train/VEERY'.
# There are 0 directories and 166 images in './archive/train/COCKATOO'.
# There are 0 directories and 144 images in './archive/train/GREAT GRAY OWL'.
# There are 0 directories and 156 images in './archive/train/PEREGRINE FALCON'.
# There are 0 directories and 156 images in './archive/train/NORTHERN JACANA'.
# There are 0 directories and 163 images in './archive/train/BLACK THROATED BUSHTIT'.
# There are 0 directories and 157 images in './archive/train/DOWNY WOODPECKER'.
# There are 0 directories and 187 images in './archive/train/AFRICAN PIED HORNBILL'.
# There are 0 directories and 143 images in './archive/train/GREY HEADED FISH EAGLE'.
# There are 0 directories and 142 images in './archive/train/BEARDED BELLBIRD'.
# There are 0 directories and 181 images in './archive/train/BLACK HEADED CAIQUE'.
# There are 0 directories and 172 images in './archive/train/FOREST WAGTAIL'.
# There are 0 directories and 175 images in './archive/train/VIOLET CUCKOO'.
# There are 0 directories and 220 images in './archive/train/ASIAN GREEN BEE EATER'.
# There are 0 directories and 196 images in './archive/train/NORTHERN PARULA'.
# There are 0 directories and 155 images in './archive/train/GOULDIAN FINCH'.
# There are 0 directories and 156 images in './archive/train/GREEN JAY'.
# There are 0 directories and 155 images in './archive/train/BLUE COAU'.
# There are 0 directories and 201 images in './archive/train/VIOLET BACKED STARLING'.
# There are 0 directories and 162 images in './archive/train/CINNAMON FLYCATCHER'.
# There are 0 directories and 182 images in './archive/train/VERDIN'.
# There are 0 directories and 173 images in './archive/train/PYGMY KINGFISHER'.
# There are 0 directories and 134 images in './archive/train/EASTERN BLUEBONNET'.
# There are 0 directories and 160 images in './archive/train/LONG-EARED OWL'.
# There are 0 directories and 166 images in './archive/train/DOUBLE EYED FIG PARROT'.
# There are 0 directories and 160 images in './archive/train/OKINAWA RAIL'.
# There are 0 directories and 248 images in './archive/train/HOUSE FINCH'.
# There are 0 directories and 140 images in './archive/train/GREEN BROADBILL'.
# There are 0 directories and 184 images in './archive/train/GREATOR SAGE GROUSE'.
# There are 0 directories and 139 images in './archive/train/ROSY FACED LOVEBIRD'.
# There are 0 directories and 154 images in './archive/train/GREEN WINGED DOVE'.
# There are 0 directories and 172 images in './archive/train/WALL CREAPER'.
# There are 0 directories and 163 images in './archive/train/COCK OF THE  ROCK'.
# There are 0 directories and 141 images in './archive/train/CHUCAO TAPACULO'.
# There are 0 directories and 164 images in './archive/train/CRESTED OROPENDOLA'.
# There are 0 directories and 152 images in './archive/train/ROUGH LEG BUZZARD'.
# There are 0 directories and 154 images in './archive/train/FAIRY PENGUIN'.
# There are 0 directories and 160 images in './archive/train/PURPLE MARTIN'.
# There are 0 directories and 160 images in './archive/train/HAWAIIAN GOOSE'.
# There are 0 directories and 139 images in './archive/train/NORTHERN FLICKER'.
# There are 0 directories and 141 images in './archive/train/MYNA'.
# There are 0 directories and 138 images in './archive/train/WHIMBREL'.
# There are 0 directories and 150 images in './archive/train/BAIKAL TEAL'.
# There are 0 directories and 160 images in './archive/train/SMITHS LONGSPUR'.
# There are 0 directories and 130 images in './archive/train/AMETHYST WOODSTAR'.
# There are 0 directories and 144 images in './archive/train/ANDEAN LAPWING'.
# There are 0 directories and 181 images in './archive/train/CRESTED SERPENT EAGLE'.
# There are 0 directories and 135 images in './archive/train/AFRICAN CROWNED CRANE'.
# There are 0 directories and 155 images in './archive/train/HOUSE SPARROW'.
# There are 0 directories and 153 images in './archive/train/WILD TURKEY'.
# There are 0 directories and 170 images in './archive/train/KING EIDER'.
# There are 0 directories and 162 images in './archive/train/VIOLET TURACO'.
# There are 0 directories and 193 images in './archive/train/RAZORBILL'.
# There are 0 directories and 149 images in './archive/train/IVORY BILLED ARACARI'.
# There are 0 directories and 164 images in './archive/train/REGENT BOWERBIRD'.
# There are 0 directories and 152 images in './archive/train/OSPREY'.
# There are 0 directories and 132 images in './archive/train/ROCK DOVE'.
# There are 0 directories and 151 images in './archive/train/VICTORIA CROWNED PIGEON'.
# There are 0 directories and 161 images in './archive/train/CINNAMON TEAL'.
# There are 0 directories and 169 images in './archive/train/SATYR TRAGOPAN'.
# There are 0 directories and 177 images in './archive/train/BROWN CREPPER'.
# There are 0 directories and 185 images in './archive/train/BLUE GROUSE'.
# There are 0 directories and 177 images in './archive/train/COLLARED ARACARI'.
# There are 0 directories and 175 images in './archive/train/LITTLE AUK'.
# There are 0 directories and 156 images in './archive/train/PEACOCK'.
# There are 0 directories and 170 images in './archive/train/ZEBRA DOVE'.
# There are 0 directories and 154 images in './archive/train/MALABAR HORNBILL'.
# There are 0 directories and 138 images in './archive/train/WATTLED CURASSOW'.
# There are 0 directories and 131 images in './archive/train/BLACK FRANCOLIN'.
# There are 0 directories and 141 images in './archive/train/COMMON STARLING'.
# There are 0 directories and 154 images in './archive/train/TIT MOUSE'.
# There are 0 directories and 185 images in './archive/train/CANVASBACK'.
# There are 0 directories and 139 images in './archive/train/TRICOLORED BLACKBIRD'.
# There are 0 directories and 192 images in './archive/train/PALM NUT VULTURE'.
# There are 0 directories and 194 images in './archive/train/BANDED BROADBILL'.
# There are 0 directories and 152 images in './archive/train/GRANDALA'.
# There are 0 directories and 216 images in './archive/train/SWINHOES PHEASANT'.
# There are 0 directories and 192 images in './archive/train/BROWN HEADED COWBIRD'.
# There are 0 directories and 155 images in './archive/train/GRAY CATBIRD'.
# There are 0 directories and 164 images in './archive/train/AVADAVAT'.
# There are 0 directories and 214 images in './archive/train/WOOD DUCK'.
# There are 0 directories and 168 images in './archive/train/LUCIFER HUMMINGBIRD'.
# There are 0 directories and 155 images in './archive/train/CAPE ROCK THRUSH'.
# There are 0 directories and 190 images in './archive/train/SNOW GOOSE'.
# There are 0 directories and 133 images in './archive/train/AMERICAN GOLDFINCH'.
# There are 0 directories and 163 images in './archive/train/CERULEAN WARBLER'.
# There are 0 directories and 153 images in './archive/train/ANHINGA'.
# There are 0 directories and 144 images in './archive/train/CRAB PLOVER'.
# There are 0 directories and 150 images in './archive/train/BLUE THROATED TOUCANET'.
# There are 0 directories and 157 images in './archive/train/EGYPTIAN GOOSE'.
# There are 0 directories and 164 images in './archive/train/BLACK SWAN'.
# There are 0 directories and 169 images in './archive/train/GREAT KISKADEE'.
# There are 0 directories and 190 images in './archive/train/ASIAN OPENBILL STORK'.
# There are 0 directories and 132 images in './archive/train/BLACK COCKATO'.
# There are 0 directories and 136 images in './archive/train/RED BROWED FINCH'.
# There are 0 directories and 204 images in './archive/train/JACOBIN PIGEON'.
# There are 0 directories and 151 images in './archive/train/SAND MARTIN'.
# There are 0 directories and 131 images in './archive/train/TASMANIAN HEN'.
# There are 0 directories and 135 images in './archive/train/CRANE HAWK'.
# There are 0 directories and 167 images in './archive/train/CHUKAR PARTRIDGE'.
# There are 0 directories and 159 images in './archive/train/FRIGATE'.
# There are 0 directories and 137 images in './archive/train/CAPPED HERON'.
# There are 0 directories and 163 images in './archive/train/TURKEY VULTURE'.
# There are 0 directories and 142 images in './archive/train/CRESTED FIREBACK'.
# There are 0 directories and 188 images in './archive/train/ASHY STORM PETREL'.
# There are 0 directories and 159 images in './archive/train/JACK SNIPE'.
# There are 0 directories and 160 images in './archive/train/LARK BUNTING'.
# There are 0 directories and 194 images in './archive/train/WOODLAND KINGFISHER'.
# There are 0 directories and 133 images in './archive/train/RED HEADED WOODPECKER'.
# There are 0 directories and 209 images in './archive/train/FRILL BACK PIGEON'.
# There are 0 directories and 155 images in './archive/train/CAATINGA CACHOLOTE'.
# There are 0 directories and 153 images in './archive/train/RED FACED CORMORANT'.
# There are 0 directories and 130 images in './archive/train/PATAGONIAN SIERRA FINCH'.
# There are 0 directories and 162 images in './archive/train/FLAME BOWERBIRD'.
# There are 0 directories and 163 images in './archive/train/PAINTED BUNTING'.
# There are 0 directories and 150 images in './archive/train/FIERY MINIVET'.
# There are 0 directories and 168 images in './archive/train/BLACK-THROATED SPARROW'.
# There are 0 directories and 163 images in './archive/train/CRESTED KINGFISHER'.
# There are 0 directories and 152 images in './archive/train/INDIGO FLYCATCHER'.
# There are 0 directories and 162 images in './archive/train/CUBAN TODY'.
# There are 0 directories and 175 images in './archive/train/SNOW PARTRIDGE'.
# There are 0 directories and 176 images in './archive/train/GREEN MAGPIE'.
# There are 0 directories and 161 images in './archive/train/INLAND DOTTEREL'.
# There are 0 directories and 185 images in './archive/train/DOUBLE BRESTED CORMARANT'.
# There are 0 directories and 139 images in './archive/train/ANTILLEAN EUPHONIA'.
# There are 0 directories and 150 images in './archive/train/FASCIATED WREN'.
# There are 0 directories and 198 images in './archive/train/BLUE THROATED PIPING GUAN'.
# There are 0 directories and 151 images in './archive/train/HARLEQUIN DUCK'.
# There are 0 directories and 190 images in './archive/train/AUSTRALASIAN FIGBIRD'.
# There are 0 directories and 150 images in './archive/train/ANTBIRD'.
# There are 0 directories and 206 images in './archive/train/LAUGHING GULL'.
# There are 0 directories and 192 images in './archive/train/ORANGE BREASTED TROGON'.
# There are 0 directories and 152 images in './archive/train/EASTERN GOLDEN WEAVER'.
# There are 0 directories and 154 images in './archive/train/ANDEAN SISKIN'.
# There are 0 directories and 186 images in './archive/train/RUBY CROWNED KINGLET'.
# There are 0 directories and 160 images in './archive/train/STEAMER DUCK'.
# There are 0 directories and 190 images in './archive/train/DUNLIN'.
# There are 0 directories and 158 images in './archive/train/GOLDEN EAGLE'.
# There are 0 directories and 138 images in './archive/train/LILAC ROLLER'.
# There are 0 directories and 152 images in './archive/train/CALIFORNIA CONDOR'.
# There are 0 directories and 140 images in './archive/train/POMARINE JAEGER'.
# There are 0 directories and 196 images in './archive/train/COPPERSMITH BARBET'.
# There are 0 directories and 209 images in './archive/train/PYRRHULOXIA'.
# There are 0 directories and 163 images in './archive/train/INCA TERN'.
# There are 0 directories and 172 images in './archive/train/RED SHOULDERED HAWK'.
# There are 0 directories and 155 images in './archive/train/AMERICAN KESTREL'.
# There are 0 directories and 141 images in './archive/train/ASIAN DOLLARD BIRD'.
# There are 0 directories and 132 images in './archive/train/SCARLET TANAGER'.
# There are 0 directories and 160 images in './archive/train/GRAY PARTRIDGE'.
# There are 0 directories and 198 images in './archive/train/CRIMSON SUNBIRD'.
# There are 0 directories and 164 images in './archive/train/GRAY KINGBIRD'.
# There are 0 directories and 141 images in './archive/train/IBISBILL'.
# There are 0 directories and 150 images in './archive/train/FIRE TAILLED MYZORNIS'.
# There are 0 directories and 158 images in './archive/train/JAPANESE ROBIN'.
# There are 0 directories and 138 images in './archive/train/CUBAN TROGON'.
# There are 0 directories and 164 images in './archive/train/JAVA SPARROW'.
# There are 0 directories and 159 images in './archive/train/OCELLATED TURKEY'.
# There are 0 directories and 157 images in './archive/train/HORNED GUAN'.
# There are 0 directories and 161 images in './archive/train/CLARKS NUTCRACKER'.
# There are 0 directories and 162 images in './archive/train/CINNAMON ATTILA'.
# There are 0 directories and 152 images in './archive/train/QUETZAL'.
# There are 0 directories and 153 images in './archive/train/BLOOD PHEASANT'.
# There are 0 directories and 154 images in './archive/train/NICOBAR PIGEON'.
# There are 0 directories and 160 images in './archive/train/SCARLET FACED LIOCICHLA'.
# There are 0 directories and 187 images in './archive/train/AUCKLAND SHAQ'.
# There are 0 directories and 160 images in './archive/train/BEARDED BARBET'.
# There are 0 directories and 160 images in './archive/train/STRIPPED SWALLOW'.
# There are 0 directories and 154 images in './archive/train/CRIMSON CHAT'.
# There are 0 directories and 169 images in './archive/train/SUNBITTERN'.
# There are 0 directories and 159 images in './archive/train/YELLOW HEADED BLACKBIRD'.
# There are 0 directories and 156 images in './archive/train/ASIAN CRESTED IBIS'.
# There are 0 directories and 137 images in './archive/train/AZURE TANAGER'.
# There are 0 directories and 156 images in './archive/train/LOONEY BIRDS'.
# There are 0 directories and 132 images in './archive/train/MASKED BOOBY'.
# There are 0 directories and 150 images in './archive/train/HIMALAYAN BLUETAIL'.
# There are 0 directories and 182 images in './archive/train/OILBIRD'.
# There are 0 directories and 145 images in './archive/train/BLACK THROATED HUET'.
# There are 0 directories and 142 images in './archive/train/ROYAL FLYCATCHER'.
# There are 0 directories and 172 images in './archive/train/BLACK BREASTED PUFFBIRD'.
# There are 0 directories and 154 images in './archive/train/SCARLET CROWNED FRUIT DOVE'.
# There are 0 directories and 143 images in './archive/train/BAY-BREASTED WARBLER'.
# There are 0 directories and 136 images in './archive/train/TOUCHAN'.
# There are 0 directories and 154 images in './archive/train/MANDRIN DUCK'.
# There are 0 directories and 154 images in './archive/train/AUSTRAL CANASTERO'.
# There are 0 directories and 175 images in './archive/train/KILLDEAR'.
# There are 0 directories and 135 images in './archive/train/GOLDEN CHLOROPHONIA'.
# There are 0 directories and 150 images in './archive/train/FAN TAILED WIDOW'.
# There are 0 directories and 157 images in './archive/train/COMMON HOUSE MARTIN'.
# There are 0 directories and 160 images in './archive/train/HELMET VANGA'.
# There are 0 directories and 155 images in './archive/train/AFRICAN OYSTER CATCHER'.
# There are 0 directories and 184 images in './archive/train/BUFFLEHEAD'.
# There are 0 directories and 159 images in './archive/train/RED NAPED TROGON'.
# There are 0 directories and 166 images in './archive/train/ALPINE CHOUGH'.
# There are 0 directories and 157 images in './archive/train/SCARLET MACAW'.
# There are 0 directories and 170 images in './archive/train/AMERICAN BITTERN'.
# There are 0 directories and 203 images in './archive/train/GREATER PRAIRIE CHICKEN'.
# There are 0 directories and 157 images in './archive/train/BOBOLINK'.
# There are 0 directories and 133 images in './archive/train/COMMON IORA'.
# There are 0 directories and 155 images in './archive/train/WILSONS BIRD OF PARADISE'.
# There are 0 directories and 166 images in './archive/train/EURASIAN BULLFINCH'.
# There are 0 directories and 165 images in './archive/train/ENGGANO MYNA'.
# There are 0 directories and 146 images in './archive/train/DAURIAN REDSTART'.
# There are 0 directories and 143 images in './archive/train/BURCHELLS COURSER'.
# There are 0 directories and 144 images in './archive/train/ELEGANT TROGON'.
# There are 0 directories and 159 images in './archive/train/GOLDEN PHEASANT'.
# There are 0 directories and 179 images in './archive/train/ABYSSINIAN GROUND HORNBILL'.
# There are 0 directories and 135 images in './archive/train/MALLARD DUCK'.
# There are 0 directories and 158 images in './archive/train/GOLDEN PIPIT'.
# There are 0 directories and 186 images in './archive/train/BLUE MALKOHA'.
# There are 0 directories and 153 images in './archive/train/APOSTLEBIRD'.
# There are 0 directories and 179 images in './archive/train/AMERICAN PIPIT'.
# There are 0 directories and 189 images in './archive/train/GREAT ARGUS'.
# There are 0 directories and 162 images in './archive/train/CHIPPING SPARROW'.
# There are 0 directories and 133 images in './archive/train/CAPE LONGCLAW'.
# There are 0 directories and 154 images in './archive/train/NORTHERN GANNET'.
# There are 0 directories and 143 images in './archive/train/MALAGASY WHITE EYE'.
# There are 0 directories and 160 images in './archive/train/CRESTED AUKLET'.
# There are 0 directories and 180 images in './archive/train/CEDAR WAXWING'.
# There are 0 directories and 132 images in './archive/train/ALBATROSS'.
# There are 0 directories and 195 images in './archive/train/WILLOW PTARMIGAN'.
# There are 0 directories and 180 images in './archive/train/ABBOTTS BOOBY'.
# There are 0 directories and 168 images in './archive/train/BAR-TAILED GODWIT'.
# There are 0 directories and 186 images in './archive/train/INDIAN PITTA'.
# There are 0 directories and 132 images in './archive/train/BARN SWALLOW'.
# There are 0 directories and 177 images in './archive/train/COMMON GRACKLE'.
# There are 0 directories and 161 images in './archive/train/SPLENDID WREN'.
# There are 0 directories and 161 images in './archive/train/OSTRICH'.
# There are 0 directories and 156 images in './archive/train/CRESTED SHRIKETIT'.
# There are 0 directories and 195 images in './archive/train/BLUE GRAY GNATCATCHER'.
# There are 0 directories and 153 images in './archive/train/WHITE CHEEKED TURACO'.
# There are 0 directories and 130 images in './archive/train/EURASIAN GOLDEN ORIOLE'.
# There are 0 directories and 185 images in './archive/train/NORTHERN BEARDLESS TYRANNULET'.
# There are 0 directories and 154 images in './archive/train/SUPERB STARLING'.
# There are 0 directories and 160 images in './archive/train/RED HEADED DUCK'.
# There are 0 directories and 138 images in './archive/train/GREAT POTOO'.
# There are 0 directories and 160 images in './archive/train/BORNEAN LEAFBIRD'.
# There are 0 directories and 154 images in './archive/train/CAPE GLOSSY STARLING'.
# There are 0 directories and 174 images in './archive/train/ROSE BREASTED GROSBEAK'.
# There are 0 directories and 153 images in './archive/train/INDIGO BUNTING'.
# There are 0 directories and 132 images in './archive/train/SNOWY EGRET'.
# There are 0 directories and 139 images in './archive/train/EMERALD TANAGER'.
# There are 0 directories and 156 images in './archive/train/TURQUOISE MOTMOT'.
# There are 0 directories and 150 images in './archive/train/SPOTTED CATBIRD'.
# There are 0 directories and 154 images in './archive/train/TROPICAL KINGBIRD'.
# There are 0 directories and 176 images in './archive/train/WHITE EARED HUMMINGBIRD'.
# There are 0 directories and 200 images in './archive/train/LIMPKIN'.
# There are 0 directories and 159 images in './archive/train/DALMATIAN PELICAN'.
# There are 0 directories and 152 images in './archive/train/RING-NECKED PHEASANT'.
# There are 0 directories and 163 images in './archive/train/BAND TAILED GUAN'.
# There are 0 directories and 153 images in './archive/train/NORTHERN SHOVELER'.
# There are 0 directories and 144 images in './archive/train/SPOON BILED SANDPIPER'.
# There are 0 directories and 136 images in './archive/train/DARJEELING WOODPECKER'.
# There are 0 directories and 153 images in './archive/train/CHARA DE COLLAR'.
# There are 0 directories and 162 images in './archive/train/BLACK FACED SPOONBILL'.
# There are 0 directories and 155 images in './archive/train/TEAL DUCK'.
# There are 0 directories and 137 images in './archive/train/AFRICAN FIREFINCH'.
# There are 0 directories and 191 images in './archive/train/RED CROSSBILL'.
# There are 0 directories and 144 images in './archive/train/EVENING GROSBEAK'.
# There are 0 directories and 197 images in './archive/train/MARABOU STORK'.
# There are 0 directories and 165 images in './archive/train/BANANAQUIT'.
# There are 0 directories and 149 images in './archive/train/GREAT XENOPS'.
# There are 0 directories and 154 images in './archive/train/BROWN NOODY'.
# There are 0 directories and 137 images in './archive/train/GUINEAFOWL'.
# There are 0 directories and 173 images in './archive/train/BLUE DACNIS'.
# There are 0 directories and 144 images in './archive/train/BEARDED REEDLING'.
# There are 0 directories and 159 images in './archive/train/MALEO'.
# There are 0 directories and 197 images in './archive/train/CRESTED WOOD PARTRIDGE'.
# There are 0 directories and 165 images in './archive/train/AZURE TIT'.
# There are 0 directories and 160 images in './archive/train/ROADRUNNER'.
# There are 0 directories and 153 images in './archive/train/MOURNING DOVE'.
# There are 0 directories and 141 images in './archive/train/TAILORBIRD'.
# There are 0 directories and 162 images in './archive/train/GURNEYS PITTA'.
# There are 0 directories and 163 images in './archive/train/HAMERKOP'.
# There are 0 directories and 159 images in './archive/train/WHITE CRESTED HORNBILL'.
# There are 0 directories and 159 images in './archive/train/GREY CUCKOOSHRIKE'.
# There are 0 directories and 150 images in './archive/train/INDIAN VULTURE'.
# There are 0 directories and 154 images in './archive/train/KAKAPO'.
# There are 0 directories and 139 images in './archive/train/ECUADORIAN HILLSTAR'.
# There are 0 directories and 165 images in './archive/train/ALEXANDRINE PARAKEET'.
# There are 0 directories and 205 images in './archive/train/EASTERN YELLOW ROBIN'.
# There are 0 directories and 155 images in './archive/train/GILA WOODPECKER'.

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
# Get the top 20 labels
label_counts = image_df['Label'].value_counts()[:20]

plt.figure(figsize=(20, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, alpha=0.8, palette='dark:salmon_r')
plt.title('Distribution of Top 20 Labels in Image Dataset', fontsize=16)
plt.xlabel('Label', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/4c/f0gh85js6pdgrgj4rj7mkw000000gn/T/ipykernel_10946/352861934.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, alpha=0.8, palette='dark:salmon_r')

# %%
# Display 16 picture of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 16)
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()

# %%
def compute_ela_cv(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    SCALE = 15
    orig_img = cv2.imread(path)
    orig_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)
    
    cv2.imwrite(temp_filename, orig_img, [cv2.IMWRITE_JPEG_QUALITY, quality])

    # read compressed image
    compressed_img = cv2.imread(temp_filename)

    # get absolute difference between img1 and img2 and multiply by scale
    diff = SCALE * cv2.absdiff(orig_img, compressed_img)
    return diff


def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    ela_filename = 'temp_ela.png'
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)

    ela_image = ImageChops.difference(image, temp_image)

    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1

    scale = 255.0 / max_diff
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)
    
    return ela_image


def random_sample(path, extension=None):
    if extension:
        items = Path(path).glob(f'*.{extension}')
    else:
        items = Path(path).glob(f'*')
        
    items = list(items)
        
    p = random.choice(items)
    return p.as_posix()

# %%
# View random sample from the dataset
p = random_sample('./archive/train/GOLDEN EAGLE')
orig = cv2.imread(p)
orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB) / 255.0
init_val = 100
columns = 3
rows = 3

fig=plt.figure(figsize=(15, 10))
for i in range(1, columns*rows +1):
    quality=init_val - (i-1) * 8
    img = compute_ela_cv(path=p, quality=quality)
    if i == 1:
        img = orig.copy()
    ax = fig.add_subplot(rows, columns, i) 
    ax.title.set_text(f'q: {quality}')
    plt.imshow(img)
plt.show()

# %%
train_df, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
# Split the data into three categories.
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 54167 validated image filenames belonging to 525 classes.
# Found 13541 validated image filenames belonging to 525 classes.
# Found 16927 validated image filenames belonging to 525 classes.

# %%
# Data Augmentation Step
augment = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224,224),
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.1),
])

# %%
# Load the pretained model
local_weights_path = './archive/EfficientNetB0-525.h5'
pretrained_model = load_model(local_weights_path, compile=False)
pretrained_model = EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights=None,
    pooling='max'
)

pretrained_model.trainable = False

# %%
# Create checkpoint callback
checkpoint_path = "birds_classification_model_checkpoint"
checkpoint_callback = ModelCheckpoint(checkpoint_path,
                                      save_weights_only=True,
                                      monitor="val_accuracy",
                                      save_best_only=True)

# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = EarlyStopping(monitor = "val_loss", # watch the val loss metric
                               patience = 5,
                               restore_best_weights = True) # if val loss decreases for 3 epochs in a row, stop training

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# %%
inputs = pretrained_model.input
x = augment(inputs)

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dropout(0.45)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.45)(x)


outputs = Dense(525, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=150, 
    callbacks=[
        early_stopping,
        create_tensorboard_callback("training_logs", 
                                    "bird_classification"),
        checkpoint_callback,
        reduce_lr
    ]
)
# Out:
# Saving TensorBoard log files to: training_logs/bird_classification/20240128-173900
# Epoch 1/150
#  494/1693 [=======>......................] - ETA: 7:55 - loss: 6.2633 - accuracy: 0.0021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 20
#      12 model = Model(inputs=inputs, outputs=outputs)
#      14 model.compile(
#      15     optimizer=Adam(0.0001),
#      16     loss='categorical_crossentropy',
#      17     metrics=['accuracy']
#      18 )
# ---> 20 history = model.fit(
#      21     train_images,
#      22     steps_per_epoch=len(train_images),
#      23     validation_data=val_images,
#      24     validation_steps=len(val_images),
#      25     epochs=150,
#      26     callbacks=[
#      27         early_stopping,
#      28         create_tensorboard_callback("training_logs",
#      29                                     "bird_classification"),
#      30         checkpoint_callback,
#      31         reduce_lr
#      32     ]
#      33 )
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Aves_SSR/.venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
